# %% [markdown]
# <center style="font-size: 30px;"><strong>Курсова робота</strong></center>

# %% [markdown]
# <center style="font-size: 25px;"><strong>Частина 1</strong></center>
#
# ---

# %% [markdown]
# <p style="font-size: 16px;"><strong>Мета</strong>: Вивчення основних принципів роботи та використання програмних компонентів Anaconda. Інсталяція. Дослідження можливостей IPython Notebook. Підготовка розділу 1 пояснювальної записки про зроблену роботу — опис інсталяції, можливостей використання та їх ілюстрація.</p>

# %% [markdown]
# ---
# <center style="font-size: 22px;"><strong>Вступ</strong></center>
#
# ---

# %% [markdown]
# <strong>Ipython Notebook</strong> — це середовище розробки, що дає можливості для інтерактивної та ітеративної розробки проектів, пов’язаних з Data Science. Notebook інтегрує код та результати його виконання в один файл разом з графіками, текстом, математичними виразами та іншими можливими видами представлення інформації. IPython Notebook встановлюється разом з Spyder для Python 3 у дистрибутиві Anaconda.

# %% [markdown]
# <strong>Jupyter Notebook</strong> – це інтерактивне середовище розробки, яке дає змогу створювати та виконувати код у вигляді блокнотів. Він надає можливість об’єднати код, текстові описи, формули, візуалізації та інші елементи в одному документі.

# %% [markdown]
# <strong>Anaconda Navigator</strong> - це графічний інтерфейс для управління середовищами та пакетами, який постачається з дистрибутивом Anaconda для мов програмування Python та R. Anaconda Navigator спрощує створення, встановлення та використання різних середовищ Python, а також керування бібліотеками та інструментами.

# %% [markdown]
# ---
# <center style="font-size: 22px;"><strong>Інсталяція</strong></center>
#
# ---

# %% [markdown]
# <p style="font-size: 16px;">1. З сайту
# <a href="https://www.anaconda.com/download">https://www.anaconda.com/download</a> завантажуємо <strong >Anaconda Distribution</strong >:</p>

# %% [markdown]
# ![1](pics/installanaconda.jpg)

# %% [markdown]
# <p style="font-size: 16px;">2. Після завантаження запустіть <strong>Anaconda Navigator</strong>:</p>

# %% [markdown]
# ![2](pics/findanac.jpg)

# %% [markdown]
# <p style="font-size: 16px;">3. Натисніть <strong>«Install» </strong>під <strong>Jupyter Notebook</strong>:</p>

# %% [markdown]
# ![3](pics/instalacond.jpg)

# %% [markdown]
# <p style="font-size: 16px;">4. Все готово. Тепер можна розпочати працювати в <strong>Jupyter Notebook</strong>:</p>

# %% [markdown]
# ![4](pics/lunchjupy.jpg)

# %% [markdown]
# ---
# <center style="font-size: 22px;"><strong>Можливості Jupyter Notebook</strong></center>
#
# ---

# %% [markdown]
# - Кодові клітинки: Можливість введення та виконання коду в окремих клітинках.
# - Запускати код в браузері.
# - Текстові клітинки (Markdown): Додавання текстових коментарів, описів та форматування за допомогою синтаксису Markdown.

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ###### Heading 5

# %% [markdown]
# *Курсивний текст*

# %% [markdown]
# **Жирний текст**

# %% [markdown]
# ~~Перекреслений текст~~

# %% [markdown]
# Цитати
#
# > – Теорія – це, коли ви знаєте все, але нічого не працює. Практика – це коли все працює, але ніхто не знає, чому. Ми поєднуємо теорію та практику – нічого не працює і ніхто не знає чому!

# %% [markdown]
# ### Списки
# Dotted list:
# - one
# - two
# - Trees
# - four
#
# Numbered list:
# 1. one
# 2. two
# 3. Trees
# 4. four

# %% [markdown]
# - Використання LaTex: Підтримка введення формул у форматі LaTeX для математичних виразів та виводу їх у клітинках.

# %% [markdown]
# $$\int_{a}^{b} x^2 \,dx$$

# %% [markdown]
# $\alpha, \beta, \gamma, \Delta, \Sigma, \sqrt{2}$

# %% [markdown]
# $$\begin{bmatrix} 1 & 2 \\ 3 & 4 \end{bmatrix}$$

# %% [markdown]
# $x_1, a^{n+1}, \sum_{i=1}^{n} x_i$

# %% [markdown]
# $\approx, \neq, \leq, \geq, \cdot, \times$

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# - Введення та виведення даних: Зручний спосіб завантаження та виведення даних у різних форматах, таких як CSV, JSON, Excel.

# %% [markdown]
# - Можливість виведення зображеннь

# %% [markdown]
# ![5](pics/imahw.jpg)

# %% [markdown]
# <center style="font-size: 25px;"><strong>Частина 2<strong></center>

# %% [markdown]
# ---
# <center style="font-size: 20px;">Виконання та підготовка розділу 2 пояснювальної записки.</center>
#
# ---

# %% [markdown]
# <p style="font-size: 16px;"><strong>Мета</strong>: Отримати досвід використання основних засобів аналізу та візуалізації даних у середовищі IPython Notebook на модельних наборах даних.</p>

# %% [markdown]
# <p style="font-size: 16px;">В роботі використовується публічний набір даних "used cars UK". Імпортуємо необхідні бібліотеки та відкриваємо набір даних методами pandas.</p>

# %% [markdown]
# <p style="font-size: 22px;">1. Імпортуємо необхідні бібліотеки</p>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
print('ok')
# Out:
# ok

# %% [markdown]
# <p style="font-size: 20px;">2. Відкрити набір даних засобами pandas.</p>

# %% [markdown]
# <p style="font-size: 17px;">Зчитуємо дані та виводимо перші 5 рядків.</p>

# %%
df = pd.read_csv('/Users/artemakubec/Downloads/used_cars_UK.csv')
df.head()
# Out:
#    Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# ...

# %% [markdown]
#  <p style="font-size: 17px;">Видалення 'Unnamed: 0' та 'Service history'.</p>

# %%
# Вибір всіх стовпців, крім першого
df = df.iloc[:, 1:]
df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA Fabia   6900           70189               2016              3.0
# 1  Vauxhall Corsa   1495           88585               2008              4.0
# 2     Hyundai i30    949          137000               2011              NaN
# 3      MINI Hatch   2395           96731               2010              5.0
# 4  Vauxhall Corsa   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history
# 0             NaN
# 1            Full
# 2             NaN
# 3            Full
# ...

# %% [markdown]
# <p style="font-size: 22px;"> 3. Перевірка на порожні значення.

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# title                   0
# Price                   0
# Mileage(miles)          0
# Registration_Year       0
# Previous Owners      1409
# Fuel type               0
# Body type               0
# Engine                 45
# Gearbox                 0
# Doors                  25
# Seats                  35
# Emission Class         87
# Service history      3145
# dtype: int64

# %% [markdown]
# <p style="font-size: 18px;"> Заміняємо порожні значення.

# %%
df = df.fillna(method='ffill').fillna(0)

# %% [markdown]
# <p style="font-size: 22px;">4. Відображення 10 елементів для 4-ох ознак. Математичне сподівання та дисперсія. Стандартизування даних
# </p>

# %% [markdown]
# <p style="font-size: 17px;">
#  4.1 Відобразити 10 елементів для 4-ох ознак виділити зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти елементів.</p>

# %% [markdown]
# > <p style="font-size: 15px;">Виділяємо зеленим кольором максимальні елементи , а червоним мінімальні для 10-ти елементів.</p>

# %%
df.head(10)[['Price', 'Mileage(miles)', 'Engine', 'Registration_Year']].style.highlight_min(color='red').highlight_max(color='green')
# Out:
# <style type="text/css">
# #T_130ce_row0_col0, #T_130ce_row0_col3, #T_130ce_row8_col1, #T_130ce_row8_col2 {
#   background-color: green;
# }
# #T_130ce_row0_col1, #T_130ce_row1_col2, #T_130ce_row7_col2, #T_130ce_row8_col0, #T_130ce_row8_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_130ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_130ce_level0_col0" class="col_heading level0 col0" >Price</th>
#       <th id="T_130ce_level0_col1" class="col_heading level0 col1" >Mileage(miles)</th>
#       <th id="T_130ce_level0_col2" class="col_heading level0 col2" >Engine</th>
#       <th id="T_130ce_level0_col3" class="col_heading level0 col3" >Registration_Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_130ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_130ce_row0_col0" class="data row0 col0" >6900</td>
#       <td id="T_130ce_row0_col1" class="data row0 col1" >70189</td>
# ...

# %% [markdown]
# <p style="font-size: 17px;">4.2 Вирахувати математичне сподівання та дисперсію для набору даних. Стандартизувати дані.</p>

# %% [markdown]
# Математичне сподівання (μ):
#
# $ \mu = \frac{1}{N} \sum_{i=1}^{N} x_i $

# %% [markdown]
# Дисперсія ($σ^2$):
#
# $ \sigma^2 = \frac{1}{N} \sum_{i=1}^{N} (x_i - \mu)^2 $

# %%
# Вибірка чотирьох стовпців
sample_df = df[['Price', 'Mileage(miles)', 'Registration_Year']]

# Розрахунок математичного сподівання та дисперсії для кожного стовпця
mean_values = sample_df.mean()
variance_values = sample_df.var()

standardized_df = (sample_df - mean_values) / sample_df.std()

# Вивід результатів
print("Математичне сподівання:")
print(mean_values)

print("Дисперсія:")
print(variance_values)

print("Стандартизовані дані:")
print(standardized_df)
# Out:
# Математичне сподівання:
# Price                 5787.145726
# Mileage(miles)       81328.164722
# Registration_Year     2011.835007
# dtype: float64
# Дисперсія:
# Price                2.007766e+07
# Mileage(miles)       1.554002e+09
# Registration_Year    2.593422e+01
# dtype: float64
# Стандартизовані дані:
#          Price  Mileage(miles)  Registration_Year
# 0     0.248360       -0.282571           0.817858
# 1    -0.957895        0.184086          -0.753060
# 2    -1.079748        1.412244          -0.163966
# 3    -0.757038        0.390728          -0.360331
# 4    -1.068366        0.093145           0.228764
# ...        ...             ...                ...
# 3680 -0.980212       -0.130037          -1.145789
# 3681  0.268446        0.955633           0.032399
# 3682 -0.399960        1.462979           0.228764
# 3683 -0.981328        2.482490          -0.949425
# 3684 -0.845192        0.021101           0.228764
#
# [3685 rows x 3 columns]

# %% [markdown]
# <p style="font-size: 22px;">5. Візуалізація даних.</p>

# %% [markdown]
# <p style="font-size: 17px;">5.1 Будуємо lineplot діаграму.</p>

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(x=df['Price'], y=df['Mileage(miles)'])
plt.title('Графік залежності ціни від пробігу')
plt.xlabel('Ціна')
plt.ylabel('Пробіг (милі)')
plt.show()

# %% [markdown]
# <p style="font-size: 17px;">5.2 Будуємо barplot діаграму.</p>

# %%
plt.figure(figsize=(24,12))
#sns.barplot(x=df['Previous Owners'], y=df['Mileage(miles)'])
sns.barplot(x=df['Registration_Year'], y=df['Mileage(miles)'])
# Out:
# <Axes: xlabel='Registration_Year', ylabel='Mileage(miles)'>

# %% [markdown]
# <p style="font-size: 17px;">5.3 Будуємо heatmap.</p>

# %%
df['Brand'] = df['title'].str.split().str[0]

selected_brands = ['SKODA', 'Hyundai', 'Audi', 'BMW', 'Alfa', 'SEAT', 'Subaru', 'Mazda', 'Mercedes-Benz']
selected_data = df[df['Brand'].isin(selected_brands)]
average_mileage_by_brand = selected_data.groupby('Brand')['Mileage(miles)'].mean().reset_index()

# Розрахунок середньої ціни для кожної марки
average_price_by_brand = selected_data.groupby('Brand')['Price'].mean().reset_index()

# Розрахунок середнього значення для кожної марки по 'Engine'
#average_engine_by_brand = selected_data.groupby('Brand')['Engine'].mean().reset_index()

fig, axes = plt.subplots(1, 2, figsize=(24, 4))

# Побудова heatmap для 'Mileage(miles)'
heatmap_mileage = sns.heatmap(data=average_mileage_by_brand[['Mileage(miles)']].transpose(), annot=True, fmt='.2f', cmap='plasma', ax=axes[0])
heatmap_mileage.set_xticklabels(heatmap_mileage.get_xticklabels(), rotation=45, ha='right')
axes[0].set_xticks(range(len(selected_brands)))
axes[0].set_xticklabels(selected_brands)
axes[0].set_title('Середнє Mileage(miles)')

# Побудова heatmap для 'Price'
heatmap_price = sns.heatmap(data=average_price_by_brand[['Price']].transpose(), annot=True, fmt='.2f', cmap='plasma', ax=axes[1])
heatmap_price.set_xticklabels(heatmap_price.get_xticklabels(), rotation=45, ha='right')
axes[1].set_xticks(range(len(selected_brands)))
axes[1].set_xticklabels(selected_brands)
axes[1].set_title('Середня ціна')
# Out:
# Text(0.5, 1.0, 'Середня ціна')

# %% [markdown]
# <p style="font-size: 17px;">5.4 Будуємо histplot діаграму.</p>

# %%
plt.figure(figsize=(14, 6))
sns.histplot(df['Brand'], bins=len(df['Brand'].unique()), kde=False, color='lightcoral')
plt.xlabel('Brand')
plt.ylabel('Count (log scale)')
plt.xticks(rotation=80, ha='right')
plt.yscale('log')  # Встановлюємо логарифмічний масштаб для осі y

# %% [markdown]
# ## Джерела
# - https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
# - https://www.anaconda.com/
# - https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
# - https://www.edlitera.com/blog/posts/jupyter-markdown-tutorial#mcetoc_1gcor093n18
